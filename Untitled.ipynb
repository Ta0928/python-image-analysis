# %%
from PIL import Image
import os, glob
import numpy as np
# from sklearn import cross_validation
from sklearn import model_selection

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)
num_testdata = 30

# 画像の読み込み
X = []
Y = []
for index, classlabel in enumerate(classes):
    photos_dir = r'C:\Users\kt101\OneDrive\デスクトップ\mejinaai' + classlabel
    files = glob.glob(photos_dir + "/*.jpg")
    for i, file in enumerate(files):
        if i >= 30: break
        image = Image.open(file)
        image = image.convert("RGB")
        data = np.asarray(image)
        X.append(data)
        Y.append(index)

X = np.array(X)
Y = np.array(Y)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y)
xy = (X_train, X_test, y_train, y_test)
np.save("./mejina.npy", xy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-223b6fb91e76> in <module>
#      26 Y = np.array(Y)
#      27
# ---> 28 X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y)
#      29 xy = (X_train, X_test, y_train, y_test)
#      30 np.save("./mejina.npy", xy)
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2129     n_samples = _num_samples(arrays[0])
#    2130     n_train, n_test = _validate_shuffle_split(n_samples, test_size, train_size,
# -> 2131                                               default_test_size=0.25)
#    2132
#    2133     if shuffle is False:
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\sklearn\model_selection\_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    1812             'resulting train set will be empty. Adjust any of the '
#    1813             'aforementioned parameters.'.format(n_samples, test_size,
# -> 1814                                                 train_size)
#    1815         )
#    1816
#
# ValueError: With n_samples=0, test_size=0.25 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
from PIL import Image
import os, glob
import numpy as np
# from sklearn import cross_validation
from sklearn import model_selection

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)
num_testdata = 30

# 画像の読み込み
X = []
Y = []
for index, classlabel in enumerate(classes):
    photos_dir = r'C:/Users/kt101/OneDrive/デスクトップ/mejinaai' + classlabel
    files = glob.glob(photos_dir + "/*.jpg")
    for i, file in enumerate(files):
        if i >= 30: break
        image = Image.open(file)
        image = image.convert("RGB")
        data = np.asarray(image)
        X.append(data)
        Y.append(index)

X = np.array(X)
Y = np.array(Y)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y)
xy = (X_train, X_test, y_train, y_test)
np.save("./mejina.npy", xy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-08d2f9397757> in <module>
#      26 Y = np.array(Y)
#      27
# ---> 28 X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y)
#      29 xy = (X_train, X_test, y_train, y_test)
#      30 np.save("./mejina.npy", xy)
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2129     n_samples = _num_samples(arrays[0])
#    2130     n_train, n_test = _validate_shuffle_split(n_samples, test_size, train_size,
# -> 2131                                               default_test_size=0.25)
#    2132
#    2133     if shuffle is False:
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\sklearn\model_selection\_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    1812             'resulting train set will be empty. Adjust any of the '
#    1813             'aforementioned parameters.'.format(n_samples, test_size,
# -> 1814                                                 train_size)
#    1815         )
#    1816
#
# ValueError: With n_samples=0, test_size=0.25 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
from PIL import Image
import os, glob
import numpy as np
# from sklearn import cross_validation
from sklearn import model_selection

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)
image_size = 100

# 画像の読み込み
X = []
Y = []
for index, classlabel in enumerate(classes):
    photos_dir = r'C:/Users/kt101/OneDrive/デスクトップ/mejinaai' + classlabel
    files = glob.glob(photos_dir + "/*.jpg")
    for i, file in enumerate(files):
        if i >= 30: break
        image = Image.open(file)
        image = image.convert("RGB")
        image = image.resize((image_size, image_size))
        data = np.asarray(image)
        X.append(data)
        Y.append(index)

X = np.array(X)
Y = np.array(Y)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y)
xy = (X_train, X_test, y_train, y_test)
np.save("./mejina.npy", xy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-689e5d848479> in <module>
#      27 Y = np.array(Y)
#      28
# ---> 29 X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y)
#      30 xy = (X_train, X_test, y_train, y_test)
#      31 np.save("./mejina.npy", xy)
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2129     n_samples = _num_samples(arrays[0])
#    2130     n_train, n_test = _validate_shuffle_split(n_samples, test_size, train_size,
# -> 2131                                               default_test_size=0.25)
#    2132
#    2133     if shuffle is False:
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\sklearn\model_selection\_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    1812             'resulting train set will be empty. Adjust any of the '
#    1813             'aforementioned parameters.'.format(n_samples, test_size,
# -> 1814                                                 train_size)
#    1815         )
#    1816
#
# ValueError: With n_samples=0, test_size=0.25 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
from PIL import Image
import os, glob
import numpy as np
# from sklearn import cross_validation
from sklearn import model_selection

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)
image_size = 100

# 画像の読み込み
X = []
Y = []
for index, classlabel in enumerate(classes):
    photos_dir = r'C:\Users\kt101\OneDrive\デスクトップ\mejinaai' + classlabel
    files = glob.glob(photos_dir + "/*.jpg")
    for i, file in enumerate(files):
        if i >= 30: break
        image = Image.open(file)
        image = image.convert("RGB")
        image = image.resize((image_size, image_size))
        data = np.asarray(image)
        X.append(data)
        Y.append(index)

X = np.array(X)
Y = np.array(Y)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y)
xy = (X_train, X_test, y_train, y_test)
np.save("./mejina.npy", xy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-917c65ed1d44> in <module>
#      27 Y = np.array(Y)
#      28
# ---> 29 X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y)
#      30 xy = (X_train, X_test, y_train, y_test)
#      31 np.save("./mejina.npy", xy)
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2129     n_samples = _num_samples(arrays[0])
#    2130     n_train, n_test = _validate_shuffle_split(n_samples, test_size, train_size,
# -> 2131                                               default_test_size=0.25)
#    2132
#    2133     if shuffle is False:
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\sklearn\model_selection\_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    1812             'resulting train set will be empty. Adjust any of the '
#    1813             'aforementioned parameters.'.format(n_samples, test_size,
# -> 1814                                                 train_size)
#    1815         )
#    1816
#
# ValueError: With n_samples=0, test_size=0.25 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
from PIL import Image
import os, glob
import numpy as np
# from sklearn import cross_validation
from sklearn import model_selection

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)
image_size = 100

# 画像の読み込み
X = []
Y = []
for index, classlabel in enumerate(classes):
    photos_dir = r'C:\Users\kt101\OneDrive\デスクトップ\mejinaai' + classlabel
    files = glob.glob(photos_dir + "/*.jpg")
    for i, file in enumerate(files):
        if i >= 30: break
        image = Image.open(file)
        image = image.convert("RGB")
        image = image.resize((image_size, image_size))
        data = np.asarray(image)
        X.append(data)
        Y.append(index)

X = np.array(X)
Y = np.array(Y)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y)
xy = (X_train, X_test, y_train, y_test)
np.save("./mejina.npy", xy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-917c65ed1d44> in <module>
#      27 Y = np.array(Y)
#      28
# ---> 29 X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y)
#      30 xy = (X_train, X_test, y_train, y_test)
#      31 np.save("./mejina.npy", xy)
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2129     n_samples = _num_samples(arrays[0])
#    2130     n_train, n_test = _validate_shuffle_split(n_samples, test_size, train_size,
# -> 2131                                               default_test_size=0.25)
#    2132
#    2133     if shuffle is False:
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\sklearn\model_selection\_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    1812             'resulting train set will be empty. Adjust any of the '
#    1813             'aforementioned parameters.'.format(n_samples, test_size,
# -> 1814                                                 train_size)
#    1815         )
#    1816
#
# ValueError: With n_samples=0, test_size=0.25 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
from PIL import Image
import os, glob
import numpy as np
# from sklearn import cross_validation
from sklearn import model_selection

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)
image_size = 100

# 画像の読み込み
X = []
Y = []
for index, classlabel in enumerate(classes):
    photos_dir = './' + classlabel
    files = glob.glob(photos_dir + "/*.jpg")
    for i, file in enumerate(files):
        if i >= 30: break
        image = Image.open(file)
        image = image.convert("RGB")
        image = image.resize((image_size, image_size))
        data = np.asarray(image)
        X.append(data)
        Y.append(index)

X = np.array(X)
Y = np.array(Y)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y)
xy = (X_train, X_test, y_train, y_test)
np.save("./mejina.npy", xy)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import keras
import numpy as np
from keras.optimizers import RMSprop

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)

# メインの関数を定義する
def main():
    X_train, X_test, y_train, y_test = np.load("./mejina.npy",allow_pickle=True)
    X_train = X_train.astype("float") / 256
    X_test = X_test.astype("float") / 256
    y_train = np_utils.to_categorical(y_train, num_classes)
    y_test = np_utils.to_categorical(y_test, num_classes)

    model = model_train(X_train, y_train)
    model_eval(model, X_test, y_test)

def model_train(X, y):
    model = Sequential()
    model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(32,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64,(3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3))
    model.add(Activation('softmax'))

    opt = keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)
    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
    model.fit(X, y, batch_size=32, epochs
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-50-5f290f813b50> in <module>
#      59
#      60 if __name__ == "__main__":
# ---> 61     main()
#
# <ipython-input-50-5f290f813b50> in main()
#      18     y_test = np_utils.to_categorical(y_test, num_classes)
#      19
# ---> 20     model = model_train(X_train, y_train)
#      21     model_eval(model, X_test, y_test)
#      22
#
# <ipython-input-50-5f290f813b50> in model_train(X, y)
#      49
#      50     # モデルの保存
# ---> 51     model.save('./mejina_model.h5')
#      52
#      53     return model
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options)
#    1977     """
#    1978     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
# -> 1979                     signatures, options)
#    1980
#    1981   def save_weights(self,
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\saving\save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options)
#     129           'or using `save_weights`.')
#     130     hdf5_format.save_model_to_hdf5(
# --> 131         model, filepath, overwrite, include_optimizer)
#     132   else:
#     133     saved_model_save.save(model, filepath, overwrite, include_optimizer,
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#      81
#      82   if h5py is None:
# ---> 83     raise ImportError('`save_model` requires h5py.')
#      84
#      85   # TODO(psv) Add warning when we save models that contain non-serializable
#
# ImportError: `save_model` requires h5py.

# %%
from PIL import Image
import os, glob
import numpy as np
# from sklearn import cross_validation
from sklearn import model_selection

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)
num_testdata = 30

# 画像の読み込み
X_train = []
X_test = []
Y_train = []
Y_test = []

for index, classlabel in enumerate(classes):
    photos_dir = "./" + classlabel
    files = glob.glob(photos_dir + "/*.jpg")
    for i, file in enumerate(files):
        if i >= 30: break
        image = Image.open(file)
        image = image.convert("RGB")
        data = np.asarray(image)

        if i < num_testdata:
            X_test.append(data)
            Y_test.append(index)
        else:
            for angle in range(-20,20,5):
                # 回転
                img_r = image.rotate(angle)
                data = np.asarray(img_r)
                X_train.append(data)
                Y_train.append(index)

                # 反転
                img_trans = img_r.transpose(Image.FLIP_LEFT_RIGHT)
                data = np.asarray(img_trans)
                X_train.append(data)
                Y_train.append(index)

# X = np.array(X)
# Y = np.array(Y)
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(Y_train)
y_test = np.array(Y_test)

# X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y)
xy = (X_train, X_test, y_train, y_test)
np.save("./mejina_aug.npy", xy)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import keras
import numpy as np

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)

# メインの関数を定義する
def main():
    X_train, X_test, y_train, y_test = np.load("./mejina_aug.npy",allow_pickle=True)
    X_train = X_train.astype("float") / 256
    X_test = X_test.astype("float") / 256
    y_train = np_utils.to_categorical(y_train, num_classes)
    y_test = np_utils.to_categorical(y_test, num_classes)

    model = model_train(X_train, y_train)
    # model_eval(model, X_test, y_test)
    model_predict(model, X_test, y_test)

def model_train(X, y):
    model = Sequential()
    model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(32,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64,(3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3))
    model.add(Activation('softmax'))

    # opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)
    opt = keras.optimizers.adam()

    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
    model.fit(X, y, batch_size=32, epochs=100)

    # モデルの保存
    model.save('./mejina_model_aug.h5')

    return model

def model_eval(model, X, y):
    scores = model.evaluate(X, y, verbose=1)
    print('Test Loss: ', scores[0])
    print('Test Accuracy: ', scores[1])

def model_predict(model, X, y):
    result = model.predict(X)
    for i in range(X.shape[0]):
        print('推定値: ', result[i].argmax())
        print('正解値: ', y[i].argmax())
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-2c31bde7511c> in <module>
#      66         print('正解値: ', y[i].argmax())
#      67 if __name__ == "__main__":
# ---> 68     main()
#
# <ipython-input-52-2c31bde7511c> in main()
#      17     y_test = np_utils.to_categorical(y_test, num_classes)
#      18
# ---> 19     model = model_train(X_train, y_train)
#      20     # model_eval(model, X_test, y_test)
#      21     model_predict(model, X_test, y_test)
#
# <ipython-input-52-2c31bde7511c> in model_train(X, y)
#      23 def model_train(X, y):
#      24     model = Sequential()
# ---> 25     model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape[1:]))
#      26     model.add(Activation('relu'))
#      27     model.add(Conv2D(32,(3,3)))
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
#     204           # and create the node connecting the current layer
#     205           # to the input layer we just created.
# --> 206           layer(x)
#     207           set_inputs = True
#     208
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     924     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     925       return self._functional_construction_call(inputs, args, kwargs,
# --> 926                                                 input_list)
#     927
#     928     # Maintains info about the `Layer.call` stack.
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1090       # TODO(reedwm): We should assert input compatibility after the inputs
#    1091       # are casted, not before.
# -> 1092       input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#    1093       graph = backend.get_graph()
#    1094       # Use `self._name_scope()` to avoid auto-incrementing the name.
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     194                          ', found ndim=' + str(ndim) +
#     195                          '. Full shape received: ' +
# --> 196                          str(x.shape.as_list()))
#     197     # Check dtype.
#     198     if spec.dtype is not None:
#
# ValueError: Input 0 of layer conv2d_24 is incompatible with the layer: : expected min_ndim=4, found ndim=1. Full shape received: [None]

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import keras
import numpy as np

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)

# メインの関数を定義する
def main():
    X_train, X_test, y_train, y_test = np.load("./mejina_aug.npy",allow_pickle=True)
    X_train = X_train.astype("float") / 256
    X_test = X_test.astype("float") / 256
    y_train = np_utils.to_categorical(y_train, num_classes)
    y_test = np_utils.to_categorical(y_test, num_classes)

    model = model_train(X_train, y_train)
    # model_eval(model, X_test, y_test)
    model_predict(model, X_test, y_test)

def model_train(X, y):
    model = Sequential()
    model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(32,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64,(3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3))
    model.add(Activation('softmax'))

    # opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)
    opt = keras.optimizers.adam()

    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
    model.fit(X, y, batch_size=32, epochs=100)

    # モデルの保存
    model.save('./mejina_model_aug.h5')

    return model

def model_eval(model, X, y):
    scores = model.evaluate(X, y, verbose=1)
    print('Test Loss: ', scores[0])
    print('Test Accuracy: ', scores[1])

def model_predict(model, X, y):
    result = model.predict(X)
    for i in range(X.shape[0]):
        print('推定値: ', result[i].argmax())
        print('正解値: ', y[i].argmax())
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-2c31bde7511c> in <module>
#      66         print('正解値: ', y[i].argmax())
#      67 if __name__ == "__main__":
# ---> 68     main()
#
# <ipython-input-53-2c31bde7511c> in main()
#      17     y_test = np_utils.to_categorical(y_test, num_classes)
#      18
# ---> 19     model = model_train(X_train, y_train)
#      20     # model_eval(model, X_test, y_test)
#      21     model_predict(model, X_test, y_test)
#
# <ipython-input-53-2c31bde7511c> in model_train(X, y)
#      23 def model_train(X, y):
#      24     model = Sequential()
# ---> 25     model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape[1:]))
#      26     model.add(Activation('relu'))
#      27     model.add(Conv2D(32,(3,3)))
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
#     204           # and create the node connecting the current layer
#     205           # to the input layer we just created.
# --> 206           layer(x)
#     207           set_inputs = True
#     208
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     924     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     925       return self._functional_construction_call(inputs, args, kwargs,
# --> 926                                                 input_list)
#     927
#     928     # Maintains info about the `Layer.call` stack.
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1090       # TODO(reedwm): We should assert input compatibility after the inputs
#    1091       # are casted, not before.
# -> 1092       input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#    1093       graph = backend.get_graph()
#    1094       # Use `self._name_scope()` to avoid auto-incrementing the name.
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     194                          ', found ndim=' + str(ndim) +
#     195                          '. Full shape received: ' +
# --> 196                          str(x.shape.as_list()))
#     197     # Check dtype.
#     198     if spec.dtype is not None:
#
# ValueError: Input 0 of layer conv2d_25 is incompatible with the layer: : expected min_ndim=4, found ndim=1. Full shape received: [None]

# %%
from PIL import Image
import os, glob
import numpy as np
# from sklearn import cross_validation
from sklearn import model_selection

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)
num_testdata = 30

# 画像の読み込み
X_train = []
X_test = []
Y_train = []
Y_test = []

for index, classlabel in enumerate(classes):
    photos_dir = "./" + classlabel
    files = glob.glob(photos_dir + "/*.jpg")
    for i, file in enumerate(files):
        if i >= 30: break
        image = Image.open(file)
        image = image.convert("RGB")
        data = np.asarray(image)

        if i < num_testdata:
            X_test.append(data)
            Y_test.append(index)
        else:
            for angle in range(-20,20,5):
                # 回転
                img_r = image.rotate(angle)
                data = np.asarray(img_r)
                X_train.append(data)
                Y_train.append(index)

                # 反転
                img_trans = img_r.transpose(Image.FLIP_LEFT_RIGHT)
                data = np.asarray(img_trans)
                X_train.append(data)
                Y_train.append(index)

# X = np.array(X)
# Y = np.array(Y)
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(Y_train)
y_test = np.array(Y_test)

# X_train, X_test, y_train, y_test = model_selection.train_test_split(X, Y)
xy = (X_train, X_test, y_train, y_test)
np.save("./mejina_aug.npy", xy)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import keras
import numpy as np

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)
image_size = 100

# メインの関数を定義する
def main():
    X_train, X_test, y_train, y_test = np.load("./mejina_aug.npy",allow_pickle=True)
    X_train = X_train.astype("float") / 256
    X_test = X_test.astype("float") / 256
    y_train = np_utils.to_categorical(y_train, num_classes)
    y_test = np_utils.to_categorical(y_test, num_classes)

    model = model_train(X_train, y_train)
    # model_eval(model, X_test, y_test)
    model_predict(model, X_test, y_test)

def model_train(X, y):
    model = Sequential()
    model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(32,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64,(3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3))
    model.add(Activation('softmax'))

    # opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)
    opt = keras.optimizers.adam()

    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
    model.fit(X, y, batch_size=32, epochs=100)

    # モデルの保存
    model.save('./mejina_model_aug.h5')

    return model

def model_eval(model, X, y):
    scores = model.evaluate(X, y, verbose=1)
    print('Test Loss: ', scores[0])
    print('Test Accuracy: ', scores[1])

def model_predict(model, X, y):
    result = model.predict(X)
    for i in range(X.shape[0]):
        print('推定値: ', result[i].argmax())
        print('正解値: ', y[i].argmax())
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-7c3caf9c0a42> in <module>
#      67         print('正解値: ', y[i].argmax())
#      68 if __name__ == "__main__":
# ---> 69     main()
#
# <ipython-input-55-7c3caf9c0a42> in main()
#      18     y_test = np_utils.to_categorical(y_test, num_classes)
#      19
# ---> 20     model = model_train(X_train, y_train)
#      21     # model_eval(model, X_test, y_test)
#      22     model_predict(model, X_test, y_test)
#
# <ipython-input-55-7c3caf9c0a42> in model_train(X, y)
#      24 def model_train(X, y):
#      25     model = Sequential()
# ---> 26     model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape[1:]))
#      27     model.add(Activation('relu'))
#      28     model.add(Conv2D(32,(3,3)))
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
#     204           # and create the node connecting the current layer
#     205           # to the input layer we just created.
# --> 206           layer(x)
#     207           set_inputs = True
#     208
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     924     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     925       return self._functional_construction_call(inputs, args, kwargs,
# --> 926                                                 input_list)
#     927
#     928     # Maintains info about the `Layer.call` stack.
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1090       # TODO(reedwm): We should assert input compatibility after the inputs
#    1091       # are casted, not before.
# -> 1092       input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#    1093       graph = backend.get_graph()
#    1094       # Use `self._name_scope()` to avoid auto-incrementing the name.
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     194                          ', found ndim=' + str(ndim) +
#     195                          '. Full shape received: ' +
# --> 196                          str(x.shape.as_list()))
#     197     # Check dtype.
#     198     if spec.dtype is not None:
#
# ValueError: Input 0 of layer conv2d_26 is incompatible with the layer: : expected min_ndim=4, found ndim=1. Full shape received: [None]

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import keras
import numpy as np

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)
image_size = 100

# メインの関数を定義する
def main():
    X_train, X_test, y_train, y_test = np.load("./mejina_aug.npy",allow_pickle=True)
    X_train = X_train.astype("float") / 256
    X_test = X_test.astype("float") / 256
    y_train = np_utils.to_categorical(y_train, num_classes)
    y_test = np_utils.to_categorical(y_test, num_classes)

    model = model_train(X_train, y_train)
    # model_eval(model, X_test, y_test)
    model_predict(model, X_test, y_test)

def model_train(X, y):
    model = Sequential()
    model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape(100,100,3)))
    model.add(Activation('relu'))
    model.add(Conv2D(32,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64,(3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3))
    model.add(Activation('softmax'))

    # opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)
    opt = keras.optimizers.adam()

    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
    model.fit(X, y, batch_size=32, epochs=100)

    # モデルの保存
    model.save('./mejina_model_aug.h5')

    return model

def model_eval(model, X, y):
    scores = model.evaluate(X, y, verbose=1)
    print('Test Loss: ', scores[0])
    print('Test Accuracy: ', scores[1])

def model_predict(model, X, y):
    result = model.predict(X)
    for i in range(X.shape[0]):
        print('推定値: ', result[i].argmax())
        print('正解値: ', y[i].argmax())
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-1552258785fc> in <module>
#      67         print('正解値: ', y[i].argmax())
#      68 if __name__ == "__main__":
# ---> 69     main()
#
# <ipython-input-56-1552258785fc> in main()
#      18     y_test = np_utils.to_categorical(y_test, num_classes)
#      19
# ---> 20     model = model_train(X_train, y_train)
#      21     # model_eval(model, X_test, y_test)
#      22     model_predict(model, X_test, y_test)
#
# <ipython-input-56-1552258785fc> in model_train(X, y)
#      24 def model_train(X, y):
#      25     model = Sequential()
# ---> 26     model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape(100,100,3)))
#      27     model.add(Activation('relu'))
#      28     model.add(Conv2D(32,(3,3)))
#
# TypeError: 'tuple' object is not callable

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import keras
import numpy as np

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)
image_size = 100

# メインの関数を定義する
def main():
    X_train, X_test, y_train, y_test = np.load("./mejina_aug.npy",allow_pickle=True)
    X_train = X_train.astype("float") / 256
    X_test = X_test.astype("float") / 256
    y_train = np_utils.to_categorical(y_train, num_classes)
    y_test = np_utils.to_categorical(y_test, num_classes)

    model = model_train(X_train, y_train)
    # model_eval(model, X_test, y_test)
    model_predict(model, X_test, y_test)

def model_train(X, y):
    model = Sequential()
    model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape(100,100)))
    model.add(Activation('relu'))
    model.add(Conv2D(32,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64,(3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3))
    model.add(Activation('softmax'))

    # opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)
    opt = keras.optimizers.adam()

    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
    model.fit(X, y, batch_size=32, epochs=100)

    # モデルの保存
    model.save('./mejina_model_aug.h5')

    return model

def model_eval(model, X, y):
    scores = model.evaluate(X, y, verbose=1)
    print('Test Loss: ', scores[0])
    print('Test Accuracy: ', scores[1])

def model_predict(model, X, y):
    result = model.predict(X)
    for i in range(X.shape[0]):
        print('推定値: ', result[i].argmax())
        print('正解値: ', y[i].argmax())
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-835c2d1acd5b> in <module>
#      67         print('正解値: ', y[i].argmax())
#      68 if __name__ == "__main__":
# ---> 69     main()
#
# <ipython-input-57-835c2d1acd5b> in main()
#      18     y_test = np_utils.to_categorical(y_test, num_classes)
#      19
# ---> 20     model = model_train(X_train, y_train)
#      21     # model_eval(model, X_test, y_test)
#      22     model_predict(model, X_test, y_test)
#
# <ipython-input-57-835c2d1acd5b> in model_train(X, y)
#      24 def model_train(X, y):
#      25     model = Sequential()
# ---> 26     model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape(100,100)))
#      27     model.add(Activation('relu'))
#      28     model.add(Conv2D(32,(3,3)))
#
# TypeError: 'tuple' object is not callable

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import keras
import numpy as np

classes = ["イスズミ_square","オナガメジナ_square","クチブトメジナ_square"]
num_classes = len(classes)
image_size = 100

# メインの関数を定義する
def main():
    X_train, X_test, y_train, y_test = np.load("./mejina_aug.npy",allow_pickle=True)
    X_train = X_train.astype("float") / 256
    X_test = X_test.astype("float") / 256
    y_train = np_utils.to_categorical(y_train, num_classes)
    y_test = np_utils.to_categorical(y_test, num_classes)

    model = model_train(X_train, y_train)
    # model_eval(model, X_test, y_test)
    model_predict(model, X_test, y_test)

def model_train(X, y):
    model = Sequential()
    model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(32,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64,(3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3))
    model.add(Activation('softmax'))

    # opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)
    opt = keras.optimizers.adam()

    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
    model.fit(X, y, batch_size=32, epochs=100)

    # モデルの保存
    model.save('./mejina_model_aug.h5')

    return model

def model_eval(model, X, y):
    scores = model.evaluate(X, y, verbose=1)
    print('Test Loss: ', scores[0])
    print('Test Accuracy: ', scores[1])

def model_predict(model, X, y):
    result = model.predict(X)
    for i in range(X.shape[0]):
        print('推定値: ', result[i].argmax())
        print('正解値: ', y[i].argmax())
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-7c3caf9c0a42> in <module>
#      67         print('正解値: ', y[i].argmax())
#      68 if __name__ == "__main__":
# ---> 69     main()
#
# <ipython-input-58-7c3caf9c0a42> in main()
#      18     y_test = np_utils.to_categorical(y_test, num_classes)
#      19
# ---> 20     model = model_train(X_train, y_train)
#      21     # model_eval(model, X_test, y_test)
#      22     model_predict(model, X_test, y_test)
#
# <ipython-input-58-7c3caf9c0a42> in model_train(X, y)
#      24 def model_train(X, y):
#      25     model = Sequential()
# ---> 26     model.add(Conv2D(32,(3,3), padding='same',input_shape=X.shape[1:]))
#      27     model.add(Activation('relu'))
#      28     model.add(Conv2D(32,(3,3)))
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
#     204           # and create the node connecting the current layer
#     205           # to the input layer we just created.
# --> 206           layer(x)
#     207           set_inputs = True
#     208
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     924     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     925       return self._functional_construction_call(inputs, args, kwargs,
# --> 926                                                 input_list)
#     927
#     928     # Maintains info about the `Layer.call` stack.
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1090       # TODO(reedwm): We should assert input compatibility after the inputs
#    1091       # are casted, not before.
# -> 1092       input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#    1093       graph = backend.get_graph()
#    1094       # Use `self._name_scope()` to avoid auto-incrementing the name.
#
# ~\anaconda3\envs\mejinaai\lib\site-packages\tensorflow\python\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     194                          ', found ndim=' + str(ndim) +
#     195                          '. Full shape received: ' +
# --> 196                          str(x.shape.as_list()))
#     197     # Check dtype.
#     198     if spec.dtype is not None:
#
# ValueError: Input 0 of layer conv2d_27 is incompatible with the layer: : expected min_ndim=4, found ndim=1. Full shape received: [None]
